# %%
import sys
sys.path.append("..")

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from factor_engines.load_data import get_price_data, compute_returns
from factor_engines.factors import (
    momentum_factor,
    volatility_factor,
    reversal_factor,
    sma_distance_factor,
    compute_all,
    zscore,
    daily_score
)
from factor_engines.portfolio import (
    rank_factor,
    long_short_weights,
    normalize,
    portfolio_returns,
    zscore_weights,
    zscore_all_factors,
    composite_factor,
    build_long_short_portfolio,
    build_zscore_portfolio_from_factor,
    build_composite_portfolio
)

plt.style.use("seaborn-v0_8")

# %%
tickers = ["AAPL", "MSFT", "GOOGL", "AMZN", "META"]

prices = get_price_data(tickers, "2015-01-01", "2025-01-01")
returns = compute_returns(prices)

prices.head()
returns.head()
# Out:
# Price          Close                                              High  \
# Ticker          AAPL      AMZN     GOOGL      META      MSFT      AAPL
# Date
# 2015-01-05 -0.028172 -0.020517 -0.019054 -0.016061 -0.009196 -0.025036
# 2015-01-06  0.000094 -0.022833 -0.024679 -0.013473 -0.014678 -0.011229
# 2015-01-07  0.014022  0.010600 -0.002941  0.000000  0.012705  0.007167
# 2015-01-08  0.038423  0.006836  0.003484  0.026658  0.029418  0.036507
# 2015-01-09  0.001072 -0.011749 -0.012211 -0.005628 -0.008405  0.009808
#
# Price                                               ...      Open            \
# Ticker          AMZN     GOOGL      META      MSFT  ...      AAPL      AMZN
# Date                                                ...
# 2015-01-05 -0.020238 -0.014576  0.004054 -0.014551  ... -0.027830 -0.017819
# 2015-01-06 -0.017446 -0.012841 -0.020946  0.000428  ... -0.016160 -0.015537
# 2015-01-07 -0.005677 -0.018649 -0.002964 -0.006203  ...  0.006195 -0.015683
# 2015-01-08  0.006174 -0.007801  0.011246  0.027766  ...  0.018937  0.009479
# 2015-01-09 -0.000891  0.002167  0.004985  0.001466  ...  0.031493  0.003863
#
# Price                                       Volume                      \
# Ticker         GOOGL      META      MSFT      AAPL      AMZN     GOOGL
# Date
# 2015-01-05 -0.010233 -0.007636 -0.006215  0.208270 -0.003234  0.555211
# 2015-01-06 -0.012615 -0.009618  0.000216  0.023514  0.268474  0.322325
# 2015-01-07 -0.018348 -0.006086 -0.008624 -0.390461 -0.249702 -0.138424
# 2015-01-08 -0.018475 -0.000261  0.016747  0.480194  0.169716  0.557057
# 2015-01-09  0.013300  0.019025  0.018396 -0.095427 -0.160601 -0.425083
#
# Price
# Ticker          META      MSFT
# Date
# 2015-01-05  0.455217  0.421295
# 2015-01-06  0.035804 -0.081313
# 2015-01-07 -0.195406 -0.201213
# 2015-01-08  0.086898  0.018242
# 2015-01-09 -0.117023 -0.192308
#
# [5 rows x 25 columns]
