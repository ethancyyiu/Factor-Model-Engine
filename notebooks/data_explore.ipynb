# %%
import sys
sys.path.append("..")

# %%
from factor_engines.load_data import get_price_data, compute_returns

tickers = ["AAPL", "MSFT", "GOOGL", "AMZN", "META"]
prices = get_price_data(tickers, "2015-01-01", "2025-01-01")

print(prices.columns)

returns = compute_returns(prices)

prices.plot(figsize=(12,6), title="Price")
returns.plot(figsize=(12,6), title="Daily Returns")
# Out:
# MultiIndex([( 'Close',  'AAPL'),
#             ( 'Close',  'AMZN'),
#             ( 'Close', 'GOOGL'),
#             ( 'Close',  'META'),
#             ( 'Close',  'MSFT'),
#             (  'High',  'AAPL'),
#             (  'High',  'AMZN'),
#             (  'High', 'GOOGL'),
#             (  'High',  'META'),
#             (  'High',  'MSFT'),
#             (   'Low',  'AAPL'),
#             (   'Low',  'AMZN'),
#             (   'Low', 'GOOGL'),
#             (   'Low',  'META'),
#             (   'Low',  'MSFT'),
#             (  'Open',  'AAPL'),
#             (  'Open',  'AMZN'),
#             (  'Open', 'GOOGL'),
#             (  'Open',  'META'),
#             (  'Open',  'MSFT'),
#             ('Volume',  'AAPL'),
#             ('Volume',  'AMZN'),
#             ('Volume', 'GOOGL'),
#             ('Volume',  'META'),
#             ('Volume',  'MSFT')],
#            names=['Price', 'Ticker'])
# <Axes: title={'center': 'Daily Returns'}, xlabel='Date'>
